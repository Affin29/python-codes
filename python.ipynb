# %%
students = ["Aditi", "Rahul", "Sameer", "Priya", "Kavya"]

# %% [markdown]
# ##### 1️⃣ Create a list
#
# Create a list of student names (at least 5 names).

# %%
a = tuple(students)
print(a)
# Out:
# ('Aditi', 'Rahul', 'Sameer', 'Priya', 'Kavya')

# %% [markdown]
# 2️⃣ Convert the list into a tuple
# - Convert that list of names into a tuple and print it.

# %%
courses = {"Math", "Python", "AI", "ML", "DS"}
print("Original set:", courses)
# Out:
# Original set: {'Math', 'ML', 'AI', 'DS', 'Python'}

# %% [markdown]
#  Create a set
#
# Create a set of unique courses (e.g., "Math", "Python", "AI", "ML", "DS").

# %%
courses.add("Java")
print("Updated set:", courses)
# Out:
# Updated set: {'Math', 'ML', 'Java', 'AI', 'DS', 'Python'}

# %% [markdown]
# Add one more course to the set.

# %%
courses.add('Python')
print("After adding duplicate 'Python':", courses)
# Out:
# After adding duplicate 'Python': {'Math', 'ML', 'Java', 'AI', 'DS', 'Python'}

# %% [markdown]
# Try adding a duplicate course and see what happens.

# %%
student = {
    "Aditi": 88,
    "Rahul": 90,

}

print("Original Dictionary:", student)
# Out:
# Original Dictionary: {'Aditi': 88, 'Rahul': 90}

# %% [markdown]
# Create a dictionary where:

# %%
student["Rohan"] = 80
print("After Add Rohan:", student)
# Out:
# After Add Rohan: {'Aditi': 88, 'Rahul': 90, 'Rohan': 80}

# %% [markdown]
# Add one more student

# %%
student["Rahul"] = 99
print("After Updating rahul Marks:", student)
# Out:
# After Updating rahul Marks: {'Aditi': 88, 'Rahul': 99, 'Rohan': 80}

# %% [markdown]
# Update marks of one student

# %%
del student["Aditi"]
print("After Deleting Aditi:", student)
# Out:
# After Deleting Aditi: {'Rahul': 99, 'Rohan': 80}

# %% [markdown]
# Delete one student

# %%
# 1️⃣ List of students
students = ["Aditi", "Rahul", "Sameer", "Priya", "Kavya"]
print("List of Students:", students)

# 2️⃣ Convert list to tuple
students_tuple = tuple(students)
print("Tuple of Students:", students_tuple)

# 3️⃣ Set of unique courses
courses = {"Math", "Python", "AI", "ML", "DS"}
courses.add("NLP")          # add new course
courses.add("Python")       # duplicate (ignored by set)
print("Set of Courses:", courses)

# 4️⃣ Dictionary of student marks
student_marks = {
    "Rahul": 90,
    "Arjun": 85,
    "Sneha": 78,
    "Vikram": 88,
    "Neha": 92
}

# Add one student
student_marks["Rohan"] = 80

# Update marks
student_marks["Sneha"] = 82

# Delete one student
del student_marks["Arjun"]

print("Dictionary of Student Marks:", student_marks)
# Out:
# List of Students: ['Aditi', 'Rahul', 'Sameer', 'Priya', 'Kavya']
# Tuple of Students: ('Aditi', 'Rahul', 'Sameer', 'Priya', 'Kavya')
# Set of Courses: {'Math', 'ML', 'NLP', 'AI', 'DS', 'Python'}
# Dictionary of Student Marks: {'Rahul': 90, 'Sneha': 82, 'Vikram': 88, 'Neha': 92, 'Rohan': 80}
